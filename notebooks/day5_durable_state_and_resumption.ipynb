# %% [markdown]
# # Day 5 - Durable State and Resumption
#
# This notebook parks the golden-thread case at the controller gate and then resumes it from PostgreSQL.

# %% [markdown]
# ## Apply The Migration
#
# Use the full Azure track or set `AEGISAP_POSTGRES_DSN` before running the cells below.

# %%
# !uv run python scripts/apply_migrations.py

# %%
# !uv run python scripts/run_day4_case.py --planner-mode fixture
# !uv run python scripts/run_day5_pause_resume.py
# !uv run python scripts/resume_day5_case.py --status approved
